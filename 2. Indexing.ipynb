# %%
import pandas as pd

# %%
pd.set_option("display.max.rows",235)
pd.set_option("display.max.columns",18)

# %%
pop = pd.read_csv(r"C:\Users\adeeb.arif\Downloads\world_population.csv",index_col="Country/Territory")
pop
# Out:
#                                   Rank CCA3              Capital  \
# Country/Territory
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
pop.reset_index(inplace=True)
pop
# Out:
#                     Country/Territory  Rank CCA3              Capital  \
# 0                         Afghanistan    36  AFG                Kabul
# 1                             Albania   138  ALB               Tirana
# 2                             Algeria    34  DZA              Algiers
# 3                      American Samoa   213  ASM            Pago Pago
# 4                             Andorra   203  AND     Andorra la Vella
# 5                              Angola    42  AGO               Luanda
# 6                            Anguilla   224  AIA           The Valley
# 7                 Antigua and Barbuda   201  ATG         Saint John’s
# 8                           Argentina    33  ARG         Buenos Aires
# 9                             Armenia   140  ARM              Yerevan
# 10                              Aruba   198  ABW           Oranjestad
# 11                          Australia    55  AUS             Canberra
# ...

# %%
pop.set_index("Country/Territory",inplace=True)
pop
# Out:
#                                   Rank CCA3              Capital  \
# Country/Territory
# Afghanistan                         36  AFG                Kabul
# Albania                            138  ALB               Tirana
# Algeria                             34  DZA              Algiers
# American Samoa                     213  ASM            Pago Pago
# Andorra                            203  AND     Andorra la Vella
# Angola                              42  AGO               Luanda
# Anguilla                           224  AIA           The Valley
# Antigua and Barbuda                201  ATG         Saint John’s
# Argentina                           33  ARG         Buenos Aires
# Armenia                            140  ARM              Yerevan
# Aruba                              198  ABW           Oranjestad
# Australia                           55  AUS             Canberra
# Austria                             99  AUT               Vienna
# ...

# %%
pop.reset_index(inplace=True)
pop
# Out:
#                     Country/Territory  Rank CCA3              Capital  \
# 0                         Afghanistan    36  AFG                Kabul
# 1                             Albania   138  ALB               Tirana
# 2                             Algeria    34  DZA              Algiers
# 3                      American Samoa   213  ASM            Pago Pago
# 4                             Andorra   203  AND     Andorra la Vella
# 5                              Angola    42  AGO               Luanda
# 6                            Anguilla   224  AIA           The Valley
# 7                 Antigua and Barbuda   201  ATG         Saint John’s
# 8                           Argentina    33  ARG         Buenos Aires
# 9                             Armenia   140  ARM              Yerevan
# 10                              Aruba   198  ABW           Oranjestad
# 11                          Australia    55  AUS             Canberra
# ...

# %%
pop.set_index(["Continent","Country/Territory"],inplace=True)
pop
# Out:
#                                                 Rank CCA3  \
# Continent     Country/Territory
# Asia          Afghanistan                         36  AFG
# Europe        Albania                            138  ALB
# Africa        Algeria                             34  DZA
# Oceania       American Samoa                     213  ASM
# Europe        Andorra                            203  AND
# Africa        Angola                              42  AGO
# North America Anguilla                           224  AIA
#               Antigua and Barbuda                201  ATG
# South America Argentina                           33  ARG
# Asia          Armenia                            140  ARM
# North America Aruba                              198  ABW
# Oceania       Australia                           55  AUS
# Europe        Austria                             99  AUT
# Asia          Azerbaijan                          91  AZE
# North America Bahamas                            176  BHS
# ...

# %%
pop.sort_index(ascending=[True,False],inplace=True)

# %%
pop
# Out:
#                                                 Rank CCA3  \
# Continent     Country/Territory
# Africa        Zimbabwe                            74  ZWE
#               Zambia                              63  ZMB
#               Western Sahara                     172  ESH
#               Uganda                              31  UGA
#               Tunisia                             79  TUN
#               Togo                               100  TGO
#               Tanzania                            22  TZA
#               Sudan                               32  SDN
#               South Sudan                         86  SSD
#               South Africa                        24  ZAF
#               Somalia                             70  SOM
#               Sierra Leone                       102  SLE
#               Seychelles                         196  SYC
#               Senegal                             72  SEN
#               Sao Tome and Principe              187  STP
# ...

# %%
pop.loc["Africa"]
# Out:
#                           Rank CCA3       Capital  2022 Population  \
# Country/Territory
# Zimbabwe                    74  ZWE        Harare         16320537
# Zambia                      63  ZMB        Lusaka         20017675
# Western Sahara             172  ESH      El Aaiún           575986
# Uganda                      31  UGA       Kampala         47249585
# Tunisia                     79  TUN         Tunis         12356117
# Togo                       100  TGO          Lomé          8848699
# Tanzania                    22  TZA        Dodoma         65497748
# Sudan                       32  SDN      Khartoum         46874204
# South Sudan                 86  SSD          Juba         10913164
# South Africa                24  ZAF      Pretoria         59893885
# Somalia                     70  SOM     Mogadishu         17597511
# Sierra Leone               102  SLE      Freetown          8605718
# Seychelles                 196  SYC      Victoria           107118
# ...

# %%
pop.loc["Africa","Zambia"]
# Out:
# Rank                                 63
# CCA3                                ZMB
# Capital                          Lusaka
# 2022 Population                20017675
# 2020 Population                18927715
# 2015 Population                16248230
# 2010 Population                13792086
# 2000 Population                 9891136
# 1990 Population                 7686401
# 1980 Population                 5720438
# 1970 Population                 4281671
# Area (km²)                       752612
# Density (per km²)               26.5976
# Growth Rate                       1.028
# World Population Percentage        0.25
# Name: (Africa, Zambia), dtype: object
