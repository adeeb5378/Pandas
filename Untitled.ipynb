# %% [markdown]
# https://www.youtube.com/watch?v=R67XuYc9NQ4

# %%
# !pip install fredapi /dev/null
# Out:
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# ERROR: Invalid requirement: '/dev/null'
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

plt.style.use('fivethirtyeight')
pd.set_option('display.max.columns',500)

cololr_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]

from fredapi import Fred

fred_key = '9e49e44eeadad7d0a0bfcb16e9cbb5d9'

# %% [markdown]
# ### 1. Create the fred Object

# %%
fred = Fred(api_key=fred_key)

# %% [markdown]
# ### 2. Search for economic Data!

# %%
spfred.search("S&P",order_by='popularity')
# Out:
#                                 id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2          BAMLH0A0HYM2     2023-12-30   2023-12-30
# CSUSHPINSA              CSUSHPINSA     2023-12-30   2023-12-30
# SP500                        SP500     2023-12-30   2023-12-30
# MEHOINUSA672N        MEHOINUSA672N     2023-12-30   2023-12-30
# BAMLH0A0HYM2EY      BAMLH0A0HYM2EY     2023-12-30   2023-12-30
# ...                            ...            ...          ...
# CSHMCPROA156NRUG  CSHMCPROA156NRUG     2023-12-30   2023-12-30
# CSHRCPQAA156NRUG  CSHRCPQAA156NRUG     2023-12-30   2023-12-30
# CSHRCPSEA156NRUG  CSHRCPSEA156NRUG     2023-12-30   2023-12-30
# DDEM01ECA156NWDB  DDEM01ECA156NWDB     2023-12-30   2023-12-30
# DDEM01TTA156NWDB  DDEM01TTA156NWDB     2023-12-30   2023-12-30
#
#                                                               title  \
# series id
# BAMLH0A0HYM2      ICE BofA US High Yield Index Option-Adjusted S...
# CSUSHPINSA          S&P/Case-Shiller U.S. National Home Price Index
# SP500                                                       S&P 500
# MEHOINUSA672N     Real Median Household Income in the United States
# BAMLH0A0HYM2EY         ICE BofA US High Yield Index Effective Yield
# ...                                                             ...
# CSHMCPROA156NRUG  Share of Merchandise Imports at Current Purcha...
# CSHRCPQAA156NRUG  Share of Residual Trade and GDP Statistical Di...
# CSHRCPSEA156NRUG  Share of Residual Trade and GDP Statistical Di...
# DDEM01ECA156NWDB  Stock Market Turnover Ratio (Value Traded/Capi...
# DDEM01TTA156NWDB  Stock Market Turnover Ratio (Value Traded/Capi...
#
#                  observation_start observation_end     frequency  \
# series id
# BAMLH0A0HYM2            1996-12-31      2023-12-28  Daily, Close
# CSUSHPINSA              1987-01-01      2023-10-01       Monthly
# SP500                   2013-12-30      2023-12-29  Daily, Close
# MEHOINUSA672N           1984-01-01      2022-01-01        Annual
# BAMLH0A0HYM2EY          1996-12-31      2023-12-28  Daily, Close
# ...                            ...             ...           ...
# CSHMCPROA156NRUG        1960-01-01      2019-01-01        Annual
# CSHRCPQAA156NRUG        1970-01-01      2019-01-01        Annual
# CSHRCPSEA156NRUG        1950-01-01      2019-01-01        Annual
# DDEM01ECA156NWDB        1995-01-01      2000-01-01        Annual
# DDEM01TTA156NWDB        2000-01-01      2001-01-01        Annual
#
#                  frequency_short                           units  \
# series id
# BAMLH0A0HYM2                   D                         Percent
# CSUSHPINSA                     M              Index Jan 2000=100
# SP500                          D                           Index
# MEHOINUSA672N                  A  2022 CPI-U-RS Adjusted Dollars
# BAMLH0A0HYM2EY                 D                         Percent
# ...                          ...                             ...
# CSHMCPROA156NRUG               A                         Percent
# CSHRCPQAA156NRUG               A                         Percent
# CSHRCPSEA156NRUG               A                         Percent
# DDEM01ECA156NWDB               A                         Percent
# DDEM01TTA156NWDB               A                         Percent
#
#                                units_short      seasonal_adjustment  \
# series id
# BAMLH0A0HYM2                             %  Not Seasonally Adjusted
# CSUSHPINSA              Index Jan 2000=100  Not Seasonally Adjusted
# SP500                                Index  Not Seasonally Adjusted
# MEHOINUSA672N     2022 CPI-U-RS Adjusted $  Not Seasonally Adjusted
# BAMLH0A0HYM2EY                           %  Not Seasonally Adjusted
# ...                                    ...                      ...
# CSHMCPROA156NRUG                         %  Not Seasonally Adjusted
# CSHRCPQAA156NRUG                         %  Not Seasonally Adjusted
# CSHRCPSEA156NRUG                         %  Not Seasonally Adjusted
# DDEM01ECA156NWDB                         %  Not Seasonally Adjusted
# DDEM01TTA156NWDB                         %  Not Seasonally Adjusted
#
#                  seasonal_adjustment_short               last_updated  \
# series id
# BAMLH0A0HYM2                           NSA  2023-12-29 09:58:05-06:00
# CSUSHPINSA                             NSA  2023-12-26 08:12:02-06:00
# SP500                                  NSA  2023-12-29 19:11:01-06:00
# MEHOINUSA672N                          NSA  2023-09-12 13:48:02-05:00
# BAMLH0A0HYM2EY                         NSA  2023-12-29 09:58:08-06:00
# ...                                    ...                        ...
# CSHMCPROA156NRUG                       NSA  2021-11-08 13:33:09-06:00
# CSHRCPQAA156NRUG                       NSA  2021-11-08 13:32:26-06:00
# CSHRCPSEA156NRUG                       NSA  2021-11-08 13:32:26-06:00
# DDEM01ECA156NWDB                       NSA  2022-08-04 09:48:42-05:00
# DDEM01TTA156NWDB                       NSA  2022-08-04 09:48:40-05:00
#
#                  popularity                                              notes
# series id
# BAMLH0A0HYM2             93  The ICE BofA Option-Adjusted Spreads (OASs) ar...
# CSUSHPINSA               88  For more information regarding the index, plea...
# SP500                    83  The observations for the S&P 500 represent the...
# MEHOINUSA672N            82  Household data are collected as of March.  As ...
# BAMLH0A0HYM2EY           82  This data represents the effective yield of th...
# ...                     ...                                                ...
# CSHMCPROA156NRUG          3  Source ID: csh_m  When using these data in you...
# CSHRCPQAA156NRUG          3  Source ID: csh_r  When using these data in you...
# CSHRCPSEA156NRUG          3  Source ID: csh_r  When using these data in you...
# DDEM01ECA156NWDB          3  Total value of shares traded during the period...
# DDEM01TTA156NWDB          3  Total value of shares traded during the period...
#
# [1000 rows x 15 columns]

# %% [markdown]
# ### 3. Pull Raw Data

# %%
df = fred.get_series("SP500")

# %%
df
# Out:
# 2013-12-30    1841.07
# 2013-12-31    1848.36
# 2014-01-01        NaN
# 2014-01-02    1831.98
# 2014-01-03    1831.37
#                ...
# 2023-12-25        NaN
# 2023-12-26    4774.75
# 2023-12-27    4781.58
# 2023-12-28    4783.35
# 2023-12-29    4769.83
# Length: 2610, dtype: float64

# %%
df.plot()
# Out:
# <Axes: >

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Using cached pyspark-3.5.0.tar.gz (316.9 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting py4j==0.10.9.7
#   Using cached py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py): started
#   Building wheel for pyspark (setup.py): finished with status 'done'
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425388 sha256=b4ab6d81017f3f6dbb26c999c02a2b1a4a0f9ab71afe289860693a3e9df7680a
#   Stored in directory: c:\users\adeeb.arif\appdata\local\pip\cache\wheels\72\3c\32\f0f20da5a933f8c6c5a1a2184a9e516652ed3eebeb49f5ddd0
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.7 pyspark-3.5.0
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\adeeb.arif\appdata\local\anaconda3\lib\site-packages)

# %%
import findspark
findspark.init()
import pyspark

sc = pyspark.SparkContext(appName="Pi")

# %%
df = df.to_spark()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df = df.to_spark()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_spark'
